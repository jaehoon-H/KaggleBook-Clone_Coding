# %%
import numpy as np 
import pandas as pd

# %%
train = pd.read_csv('input/sample-data/train_preprocessed.csv')
train_x = train.drop(['target'], axis=1)
train_y = train['target']
test_x = pd.read_csv('input/sample-data/test_preprocessed.csv')

# %%
from sklearn.model_selection import KFold

kf =KFold(n_splits=4, shuffle= True, random_state=71)

# %%
tr_idx, va_idx = list(kf.split(train_x))[0]
tr_x, va_x= train_x.iloc[tr_idx], train_x.iloc[va_idx]
tr_y, va_y= train_y.iloc[tr_idx], train_y.iloc[va_idx]

# %%
import xgboost as xgb

# %%
class Model:
    def __init__(self, params=None):
        self.model = None
        if params is None:
            self.params={}
        else:
            self.params=params
    
    def fit(self, tr_x, tr_y, va_x, va_y):
        params= {
            'objective':'binary:logistic', 
            'verbosity':0, 
            'random_state':71
        }
        params.update(self.params)
        num_round=10
        dtrain= xgb.DMatrix(tr_x, label = tr_y)
        dvalid = xgb.DMatrix(va_x, label = va_y)
        watchlist=[(dtrain, 'train'), (dvalid, 'eval')]
        self.model = xgb.train(params, dtrain, num_round, evals=watchlist)
    
    def predict(self, x):
        data= xgb.DMatrix(x)
        pred= self.model.predict(data)
        return pred

# %%
from hyperopt import hp

# %%
space= {
    'activation':hp.choice('activation',['prelu','relu']) ,#(label='activation', option=['prelu', 'relu'])
    'dropout':hp.uniform('dropout', 0.2),
    'units':hp.quniform('units', 32,256,32),
    'learning_rate':hp.loguniform('learning_rate', np.log(0.00001), np.log(0.01))
}

# %%
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from sklearn.metrics import log_loss

# %%
def score(params):
    params['max_depth']=int(params['max_depth'])
    
    model = Model(params)
    model.fit(tr_x, tr_y, va_x, va_y)
    va_pred= model.predict(va_x)
    score = log_loss(va_y, va_pred)
    print(f'params:{params}, logloss:{score:.4f}')
    
    history.append((params, score))
    return {'loss':score, 'status':STATUS_OK}

# %%
#탐색할 매개변수 공간 지정
space= {
    'min_child_weight': hp.quniform('min_child_weight', 1,5,1),
    'max_depth': hp.quniform('max_depth', 3,9,1),
    'gamma':hp.quniform('gamma', 0, 0.4, 0.1)
}

# %%
#hyperopt에 의한 매개변수 탐색 실행 
max_evals=10
trials= Trials()
history= []
fmin(score, space, algo=tpe.suggest, trials= trials, max_evals= max_evals)
# Out:
# [0]	train-logloss:0.55704	eval-logloss:0.56275
#
# [1]	train-logloss:0.47971	eval-logloss:0.48930
#
# [2]	train-logloss:0.43033	eval-logloss:0.44067
#
# [3]	train-logloss:0.39670	eval-logloss:0.40974
#
# [4]	train-logloss:0.36958	eval-logloss:0.38426
#
# [5]	train-logloss:0.35162	eval-logloss:0.36757
#
# [6]	train-logloss:0.33714	eval-logloss:0.35444
#
# [7]	train-logloss:0.32096	eval-logloss:0.34284
#
# [8]	train-logloss:0.30766	eval-logloss:0.33135
#
# [9]	train-logloss:0.29785	eval-logloss:0.32446
#
# params:{'gamma': 0.4, 'max_depth': 4, 'min_child_weight': 3.0}, logloss:0.3245
# [0]	train-logloss:0.53467	eval-logloss:0.54419
#
# [1]	train-logloss:0.44254	eval-logloss:0.46497
#
# [2]	train-logloss:0.38290	eval-logloss:0.41454
#
# [3]	train-logloss:0.33583	eval-logloss:0.37390
#
# [4]	train-logloss:0.30268	eval-logloss:0.34925
#
# [5]	train-logloss:0.27537	eval-logloss:0.33146
#
# [6]	train-logloss:0.25305	eval-logloss:0.31888
#
# [7]	train-logloss:0.23547	eval-logloss:0.30548
#
# [8]	train-logloss:0.21786	eval-logloss:0.29725
#
# [9]	train-logloss:0.20556	eval-logloss:0.28800
#
# params:{'gamma': 0.2, 'max_depth': 7, 'min_child_weight': 2.0}, logloss:0.2880
# [0]	train-logloss:0.54889	eval-logloss:0.55578
#
# [1]	train-logloss:0.46653	eval-logloss:0.47876
#
# [2]	train-logloss:0.41184	eval-logloss:0.42756
#
# [3]	train-logloss:0.37599	eval-logloss:0.39428
#
# [4]	train-logloss:0.34770	eval-logloss:0.37159
#
# [5]	train-logloss:0.32342	eval-logloss:0.35091
#
# [6]	train-logloss:0.30619	eval-logloss:0.33779
#
# [7]	train-logloss:0.29252	eval-logloss:0.32883
#
# [8]	train-logloss:0.27807	eval-logloss:0.31512
#
# [9]	train-logloss:0.26690	eval-logloss:0.30799
#
# params:{'gamma': 0.1, 'max_depth': 5, 'min_child_weight': 1.0}, logloss:0.3080
# [0]	train-logloss:0.54917	eval-logloss:0.55556
#
# [1]	train-logloss:0.46703	eval-logloss:0.47826
#
# [2]	train-logloss:0.41288	eval-logloss:0.42695
#
# [3]	train-logloss:0.37742	eval-logloss:0.39472
#
# [4]	train-logloss:0.35052	eval-logloss:0.37351
#
# [5]	train-logloss:0.32987	eval-logloss:0.35761
#
# [6]	train-logloss:0.30919	eval-logloss:0.33759
#
# [7]	train-logloss:0.29467	eval-logloss:0.32771
#
# [8]	train-logloss:0.27953	eval-logloss:0.31422
#
# [9]	train-logloss:0.26855	eval-logloss:0.30580
#
# params:{'gamma': 0.1, 'max_depth': 5, 'min_child_weight': 3.0}, logloss:0.3058
# [0]	train-logloss:0.54255	eval-logloss:0.54999
#
# [1]	train-logloss:0.45543	eval-logloss:0.47201
#
# [2]	train-logloss:0.39885	eval-logloss:0.42224
#
# [3]	train-logloss:0.35725	eval-logloss:0.38506
#
# [4]	train-logloss:0.32719	eval-logloss:0.36165
#
# [5]	train-logloss:0.30536	eval-logloss:0.34539
#
# [6]	train-logloss:0.28747	eval-logloss:0.33193
#
# [7]	train-logloss:0.27137	eval-logloss:0.32088
#
# [8]	train-logloss:0.25744	eval-logloss:0.31153
#
# [9]	train-logloss:0.24180	eval-logloss:0.29945
#
# params:{'gamma': 0.2, 'max_depth': 6, 'min_child_weight': 4.0}, logloss:0.2994
# [0]	train-logloss:0.53438	eval-logloss:0.54335
#
# [1]	train-logloss:0.44193	eval-logloss:0.46124
#
# [2]	train-logloss:0.38011	eval-logloss:0.40728
#
# [3]	train-logloss:0.33858	eval-logloss:0.37440
#
# [4]	train-logloss:0.30558	eval-logloss:0.34587
#
# [5]	train-logloss:0.27688	eval-logloss:0.32786
#
# [6]	train-logloss:0.25686	eval-logloss:0.31481
#
# [7]	train-logloss:0.24022	eval-logloss:0.30483
#
# [8]	train-logloss:0.22399	eval-logloss:0.29379
#
# [9]	train-logloss:0.21144	eval-logloss:0.28519
#
# params:{'gamma': 0.2, 'max_depth': 8, 'min_child_weight': 5.0}, logloss:0.2852
# [0]	train-logloss:0.52734	eval-logloss:0.54055
#
# [1]	train-logloss:0.43058	eval-logloss:0.46018
#
# [2]	train-logloss:0.36440	eval-logloss:0.40624
#
# [3]	train-logloss:0.31405	eval-logloss:0.36953
#
# [4]	train-logloss:0.27562	eval-logloss:0.34317
#
# [5]	train-logloss:0.24499	eval-logloss:0.32407
#
# [6]	train-logloss:0.22146	eval-logloss:0.30954
#
# [7]	train-logloss:0.20212	eval-logloss:0.29726
#
# [8]	train-logloss:0.18390	eval-logloss:0.28763
#
# [9]	train-logloss:0.16753	eval-logloss:0.27980
#
# params:{'gamma': 0.1, 'max_depth': 8, 'min_child_weight': 1.0}, logloss:0.2798
# [0]	train-logloss:0.55704	eval-logloss:0.56275
#
# [1]	train-logloss:0.47971	eval-logloss:0.48930
#
# [2]	train-logloss:0.43053	eval-logloss:0.44131
#
# [3]	train-logloss:0.39655	eval-logloss:0.40877
#
# [4]	train-logloss:0.37011	eval-logloss:0.38655
#
# [5]	train-logloss:0.35083	eval-logloss:0.37031
#
# [6]	train-logloss:0.33638	eval-logloss:0.35880
#
# [7]	train-logloss:0.32325	eval-logloss:0.34861
#
# [8]	train-logloss:0.30812	eval-logloss:0.33364
#
# [9]	train-logloss:0.29871	eval-logloss:0.32667
#
# params:{'gamma': 0.1, 'max_depth': 4, 'min_child_weight': 4.0}, logloss:0.3267
# [0]	train-logloss:0.52100	eval-logloss:0.54034
#
# [1]	train-logloss:0.42024	eval-logloss:0.45831
#
# [2]	train-logloss:0.34903	eval-logloss:0.40341
#
# [3]	train-logloss:0.29914	eval-logloss:0.36959
#
# [4]	train-logloss:0.25778	eval-logloss:0.34266
#
# [5]	train-logloss:0.22349	eval-logloss:0.32343
#
# [6]	train-logloss:0.19834	eval-logloss:0.31088
#
# [7]	train-logloss:0.17679	eval-logloss:0.30276
#
# [8]	train-logloss:0.15887	eval-logloss:0.29241
#
# [9]	train-logloss:0.14374	eval-logloss:0.28333
#
# params:{'gamma': 0.0, 'max_depth': 9, 'min_child_weight': 1.0}, logloss:0.2833
# [0]	train-logloss:0.54201	eval-logloss:0.55032
#
# [1]	train-logloss:0.45476	eval-logloss:0.47191
#
# [2]	train-logloss:0.39750	eval-logloss:0.42153
# [3]	train-logloss:0.35645	eval-logloss:0.38633
#
# [4]	train-logloss:0.32557	eval-logloss:0.36268
#
# [5]	train-logloss:0.30369	eval-logloss:0.34502
#
# [6]	train-logloss:0.28432	eval-logloss:0.33176
#
# [7]	train-logloss:0.26706	eval-logloss:0.32074
#
# [8]	train-logloss:0.25570	eval-logloss:0.31406
#
# [9]	train-logloss:0.24234	eval-logloss:0.30401
#
# params:{'gamma': 0.2, 'max_depth': 6, 'min_child_weight': 3.0}, logloss:0.3040
# 100%|██████████| 10/10 [00:01<00:00,  9.39trial/s, best loss: 0.27979850967898967]
# {'gamma': 0.1, 'max_depth': 8.0, 'min_child_weight': 1.0}

# %%
#기록한 정보에서 매개변수와 점수를 출력
history= sorted(history, key= lambda tpl: tpl[1])
best = history[0]
print(f'best_params:{best[0]}, score:{best[1]:.4f}')
# Out:
# best_params:{'gamma': 0.1, 'max_depth': 8, 'min_child_weight': 1.0}, score:0.2798
